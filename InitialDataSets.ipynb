# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("data/HarvardCellLines.csv").head(2)
# Out:
#   HMS LINCS Batch ID  HMS LINCS ID    Name Alternative Names  LINCS ID  \
# 0            50008-2         50008  CAL-51               NaN  LCL-1472
# 1            50029-2         50029    MCF7               NaN  LCL-1460
#
#                                       Alternative ID  \
# 0  <a href = "http://purl.obolibrary.org/obo/CLO_...
# 1  <a href = "http://purl.obolibrary.org/obo/CLO_...
#
#                                     Reference Source      Organism   Organ  \
# 0  <a href = "https://www.dsmz.de/catalogues/deta...  Homo sapiens  breast
# 1  <a href = "http://www.atcc.org/Products/All/HT...  Homo sapiens  breast
#
#   Tissue  ...                                           Provider  \
# 0    NaN  ...  Leibniz Institute DSMZ-German Collection of Mi...
# 1    NaN  ...                                               ATCC
#
#    Provider Catalog ID Provider Batch ID  \
# 0              ACC-302               NaN
# 1               HTB-22               NaN
#
#                                   Source Information Date Received  \
# 0  Obtained by Caitlin Mills (Harvard Medical Sch...           NaN
# 1  Obtained by Mario Niepel (Harvard Medical Scho...       7/16/10
#
#    HMS QC Outcome Transient Modification(s)  Date Publicly Available  \
# 0             NaN                       NaN                  4/25/12
# 1            PASS                       NaN                  4/25/12
#
#   Most Recent Update T Stage
# 0            8/24/16     4.0
# 1             4/4/16     4.0
#
# [2 rows x 39 columns]

# %%
pd.read_csv("data/HarvardSmallMolecules.csv").head(3)
# Out:
#   HMS LINCS Batch ID  HMS LINCS ID       Name    Alternative Names   LINCS ID  \
# 0        10006-101-1         10006    AZD7762                  NaN   LSM-1006
# 1        10018-101-1         10018  Neratinib              HKI-272  LSM-42778
# 2        10020-101-1         10020  Dasatinib  BMS-354825; Sprycel   LSM-1020
#
#    PubChem CID  ChEBI ID  ChEMBL ID  Molecular Mass  \
# 0   67077825.0       NaN        NaN          362.12
# 1   53398697.0       NaN   180022.0          556.20
# 2    3062316.0       NaN     1421.0          487.16
#
#                                                InChi  ... Relevant Citations  \
# 0  InChI=1S/C17H19FN4O2S/c18-11-4-1-3-10(7-11)14-...  ...                NaN
# 1  InChI=1S/C30H29ClN6O3/c1-4-39-28-16-25-23(15-2...  ...                NaN
# 2  InChI=1S/C22H26ClN7O2S/c1-14-4-3-5-16(23)20(14...  ...                NaN
#
#   Comments             Provider   Provider Batch ID Molecular Weight Purity  \
# 0      NaN  Haoyuan chemexpress     HY-999-20101012           362.42    NaN
# 1      NaN  Haoyuan chemexpress  HM-016_11-20100622           557.04    NaN
# 2      NaN  Haoyuan chemexpress     HY-999-20101220           488.01    NaN
#
#    Purification Method  Chemical Synthesis Reference  Date Publicly Available  \
# 0                  NaN                           NaN                      NaN
# 1                  NaN                           NaN                      NaN
# 2                  NaN                           NaN                      NaN
#
#    Most Recent Update
# 0          2016-04-04
# 1          2018-03-30
# 2          2016-04-04
#
# [3 rows x 22 columns]

# %%
pd.read_csv('data/HarvardDataSet.csv')
# Out:
#       Cell HMS LINCS ID Cell Name Small Molecule HMS LINCS ID  \
# 0               50211-2   HCC1806                 10390-103-1
# 1               50211-2   HCC1806                 10390-103-1
# 2               50211-2   HCC1806                 10390-103-1
# 3               50211-2   HCC1806                 10390-103-1
# 4               50211-2   HCC1806                 10390-103-1
# ...                 ...       ...                         ...
# 10705           51083-2  SUM159PT                 10194-106-1
# 10706           51083-2  SUM159PT                 10194-106-1
# 10707           51083-2  SUM159PT                 10194-106-1
# 10708           51083-2  SUM159PT                 10194-106-1
# 10709           51083-2  SUM159PT                 10194-106-1
#
#       Small Molecule Name  Small Mol Concentration (uM) Primary Target  \
# 0             Abemaciclib                      0.001000         CDK4/6
# 1             Abemaciclib                      0.003162         CDK4/6
# 2             Abemaciclib                      0.010000         CDK4/6
# 3             Abemaciclib                      0.031623         CDK4/6
# 4             Abemaciclib                      0.100000         CDK4/6
# ...                   ...                           ...            ...
# 10705        Cabozantinib                      0.100000     VEGFR2/MET
# 10706        Cabozantinib                      0.316230     VEGFR2/MET
# 10707        Cabozantinib                      1.000000     VEGFR2/MET
# 10708        Cabozantinib                      3.162300     VEGFR2/MET
# 10709        Cabozantinib                     10.000000     VEGFR2/MET
#
#           Pathway  Mean Normalized Growth Rate Inhibition Value  \
# 0      Cell cycle                                        0.9779
# 1      Cell cycle                                        0.9667
# 2      Cell cycle                                        0.9168
# 3      Cell cycle                                        0.7658
# 4      Cell cycle                                        0.7132
# ...           ...                                           ...
# 10705         RTK                                        1.0115
# 10706         RTK                                        0.9965
# 10707         RTK                                        0.9307
# 10708         RTK                                        0.7480
# 10709         RTK                                        0.1744
#
#        Increased Fraction Dead
# 0                      0.00362
# 1                     -0.00301
# 2                      0.00484
# 3                      0.01650
# 4                      0.01025
# ...                        ...
# 10705                 -0.00152
# 10706                  0.00568
# 10707                  0.03130
# 10708                  0.08743
# 10709                  0.19675
#
# [10710 rows x 9 columns]
